# %%
# import the data
import pandas as pd
df = pd.read_csv(r'../input/longley.csv')

# %%
import matplotlib.pyplot as plt
plt.scatter(df.Employed, df.GNP)

# %%
import numpy as np
np.corrcoef(df.Employed,df.GNP)[0,1]
# Out:
# 0.9835516111796693
